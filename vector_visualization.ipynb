# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai0043/data-andling/blob/main/vector_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
X_pos=0
Y_pos=0
X_direct=-1
Y_direct=-1
fig,ax=plt.subplots(figsize=(12,7))
ax.quiver(X_pos,Y_pos,X_direct,Y_direct)
ax.set_title('quiver plot with one arrow')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
X_pos=(2,1)
Y_pos=(2,1)
X_direct=(-1,-1)
Y_direct=(-1,-1)
fig,ax=plt.subplots(figsize=(12,7))
ax.quiver(X_pos,Y_pos,X_direct,Y_direct)
ax.set_title('quiver plot with one arrow')
plt.show()
