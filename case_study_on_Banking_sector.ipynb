# %% [markdown]
# <a href="https://colab.research.google.com/github/Sai0043/data-andling/blob/main/case_study_on_Banking_sector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
age_groups = ['18-25', '26-30', '31-35', '36-40', '41-45', '46-50', '51-55', '56-60', '61-65', '66-70', '71-75', '76-80']

# %%
num_age_groups = len(age_groups)

# %%
total_loans = np.random.randint(100, 1000, size=num_age_groups)
bad_loans = np.random.randint(10, total_loans.max() // 4, size=num_age_groups)
good_loans = total_loans - bad_loans

# %%
percentage_bad_loans = (bad_loans / total_loans) * 100
percentage_good_loans = (good_loans / total_loans) * 100

# %%
data = {
    'Age Group': age_groups,
    'Total Number of Loans': total_loans,
    'Number of Bad Loans': bad_loans,
    'Number of Good Loans': good_loans,
    'Percentage of Bad Loans': percentage_bad_loans,
    'Percentage of Good Loans': percentage_good_loans
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    Age Group  Total Number of Loans  Number of Bad Loans  \
# 0      18-25                    422                   71
# 1      26-30                    889                  124
# 2      31-35                    189                  132
# 3      36-40                    392                  155
# 4      41-45                    289                  109
# 5      46-50                    796                  122
# 6      51-55                    330                  167
# 7      56-60                    935                  158
# 8      61-65                    381                   10
# 9      66-70                    362                  177
# 10     71-75                    227                  153
# 11     76-80                    866                   53
#
#     Number of Good Loans  Percentage of Bad Loans  Percentage of Good Loans
# 0                    351                16.824645                 83.175355
# 1                    765                13.948256                 86.051744
# 2                     57                69.841270                 30.158730
# 3                    237                39.540816                 60.459184
# 4                    180                37.716263                 62.283737
# 5                    674                15.326633                 84.673367
# 6                    163                50.606061                 49.393939
# 7                    777                16.898396                 83.101604
# 8                    371                 2.624672                 97.375328
# 9                    185                48.895028                 51.104972
# 10                    74                67.400881                 32.599119
# 11                   813                 6.120092                 93.879908

# %%
import matplotlib.pyplot as plt


bad_loans = {'Bank A': 100, 'Bank B': 150, 'Bank C': 200}
good_loans = {'Bank A': 250, 'Bank B': 200, 'Bank C': 300}


banks = list(bad_loans.keys())


fig, ax = plt.subplots()


bar_width = 0.35


r1 = range(len(banks))
r2 = [x + bar_width for x in r1]


ax.bar(r1, list(bad_loans.values()), color='r', width=bar_width, edgecolor='grey', label='Bad Loans')
ax.bar(r2, list(good_loans.values()), color='g', width=bar_width, edgecolor='grey', label='Good Loans')


ax.set_xlabel('Banks')
ax.set_ylabel('Number of Loans')
ax.set_title('Bad Loans vs Good Loans by Bank')
ax.set_xticks([x + bar_width/2 for x in r1])
ax.set_xticklabels(banks)
ax.legend()


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


data = {
    'Age Group': ['18-25', '26-30', '31-35', '36-40', '41-45'],
    'Total Number of Loans': [500, 600, 700, 800, 900],
    'Number of Bad Loans': [50, 70, 80, 100, 120],
    'Number of Good Loans': [450, 530, 620, 700, 780],
    'Percentage of Bad Loans': [10, 11.67, 11.43, 12.5, 13.33],
    'Percentage of Good Loans': [90, 88.33, 88.57, 87.5, 86.67]
}

df = pd.DataFrame(data)


plt.figure(figsize=(10, 6))


bar_width = 0.35


r = np.arange(len(df))

plt.bar(r, df['Number of Bad Loans'], color='red', width=bar_width, edgecolor='grey', label='Bad Loans')
plt.bar(r, df['Number of Good Loans'], bottom=df['Number of Bad Loans'], color='green', width=bar_width, edgecolor='grey', label='Good Loans')

plt.xlabel('Age Group')
plt.ylabel('Number of Loans')
plt.title('Bad Loans vs Good Loans by Age Group')
plt.xticks(r, df['Age Group'])
plt.legend()

plt.show()
